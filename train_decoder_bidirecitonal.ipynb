# %%
from decoder_bidirectional import VCDecoder, run_training
from vc_dataset import VCDataset
import torchinfo
import yaml

CONFIG_PATH = "configs.yaml"


def load_config(config_path=CONFIG_PATH):
    with open(config_path, "r", encoding="utf-8") as config_file:
        return yaml.safe_load(config_file)

decoder = VCDecoder()
vc_dataset = VCDataset(config=load_config())

if vc_dataset is not None:
    print("VCDataset loaded successfully.")
    print("VCDataset Info:")
    print(f"Number of samples in the dataset: {len(vc_dataset)}")

print("=" * 67)
if decoder is not None:
    print("Decoder loaded successfully.")
    print("Decoder Info:")
    print(torchinfo.summary(decoder))
# Out:
# VCDataset loaded successfully.
# VCDataset Info:
# Number of samples in the dataset: 44057
# ===================================================================
# Decoder loaded successfully.
# Decoder Info:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# VCDecoder                                --
# ├─LSTM: 1-1                              6,037,504
# ├─ModuleList: 1-2                        --
# │    └─Sequential: 2-1                   --
# │    │    └─ConvNorm: 3-1                2,621,952
# │    │    └─BatchNorm1d: 3-2             1,024
# │    │    └─ReLU: 3-3                    --
# │    │    └─Dropout: 3-4                 --
# │    └─Sequential: 2-2                   --
# │    │    └─ConvNorm: 3-5                1,311,232
# │    │    └─BatchNorm1d: 3-6             1,024
# │    │    └─ReLU: 3-7                    --
# │    │    └─Dropout: 3-8                 --
# │    └─Sequential: 2-3                   --
# │    │    └─ConvNorm: 3-9                1,311,232
# │    │    └─BatchNorm1d: 3-10            1,024
# │    │    └─ReLU: 3-11                   --
# │    │    └─Dropout: 3-12                --
# ├─LSTM: 1-3                              37,781,504
# ├─Linear: 1-4                            163,920
# =================================================================
# Total params: 49,230,416
# Trainable params: 49,230,416
# Non-trainable params: 0
# =================================================================

# %%
# Establish training parameters (in configs[training])

if config := load_config():
    print("Configuration loaded successfully.")
    print("Configuration Info:")
    for key, value in config.items():
        if key == "training":
            print(f"{key}:")
            for sub_key, sub_value in value.items():
                print(f"  {sub_key}: {sub_value}")
# Out:
# Configuration loaded successfully.
# Configuration Info:
# training:
#   smoke_test_training: True
#   batch_size: 16
#   num_epochs: 5
#   learning_rate: 0.001
#   weight_decay: 0.0001
#   save_interval: 10
#   model_checkpoint_dir: None

# %%
# Training
config = load_config()

# Notebook-side overrides for this first real run.
# This does not modify configs.yaml on disk.
config["training"]["smoke_test_training"] = False
config["training"]["num_epochs"] = 5

train_dataset = VCDataset(config=config, split="train")
val_dataset = VCDataset(config=config, split="val")
test_dataset = VCDataset(config=config, split="test")

print("Training run setup")
print("=" * 67)
print(f"Train samples: {len(train_dataset)}")
print(f"Val samples:   {len(val_dataset)}")
print(f"Test samples:  {len(test_dataset)}")
print()
print("Training parameters")
print("=" * 67)
for key, value in config["training"].items():
    print(f"{key}: {value}")

model, optimizer, training_info = run_training(
    config=config,
    dataset=train_dataset,
    model=decoder,
)

training_history = training_info["history"]
training_history
# Out:
# Training run setup
# ===================================================================
# Train samples: 35164
# Val samples:   4501
# Test samples:  4392
#
# Training parameters
# ===================================================================
# smoke_test_training: False
# batch_size: 16
# num_epochs: 5
# learning_rate: 0.001
# weight_decay: 0.0001
# save_interval: 10
# model_checkpoint_dir: None
# Training:   0%|          | 0/2198 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 24
#      20 print("=" * 67)
#      21 for key, value in config["training"].items():
#      22     print(f"{key}: {value}")
#      23
# ---> 24 model, optimizer, training_info = run_training(
#      25     config=config,
#      26     dataset=train_dataset,
#      27     model=decoder,
#
# File d:\SLP VC Disentanglement Final\decoder.py:130, in run_training(config, dataset, model, device)
#     128 history = []
#     129 for epoch in range(1, training_config["num_epochs"] + 1):
# --> 130     train_loss = train_one_epoch(model, train_loader, optimizer, device)
#     131     history.append({"epoch": epoch, "loss": train_loss})
#     132     print(f"Epoch {epoch}/{training_config['num_epochs']} - loss: {train_loss:.4f}")
#
# File d:\SLP VC Disentanglement Final\decoder.py:47, in train_one_epoch(model, dataloader, optimizer, device, description)
#      44 batch = move_batch_to_device(batch, device)
#      46 optimizer.zero_grad(set_to_none=True)
# ---> 47 pred_mel = model(batch["content"], batch["speaker"])
#      48 loss = masked_l1_loss(pred_mel, batch["mel"], batch["mask"])
#      49 loss.backward()
#
# File d:\SLP VC Disentanglement Final\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File d:\SLP VC Disentanglement Final\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File d:\SLP VC Disentanglement Final\decoder.py:229, in VCDecoder.forward(self, content_latent, speaker_latent)
#     226 speaker_latent = speaker_latent.unsqueeze(1).expand(-1, time_steps, -1)
#     227 decoder_input = torch.cat([content_latent, speaker_latent], dim=-1)
# --> 229 output, _ = self.lstm1(decoder_input)
#     230 output = output.transpose(1, 2)
#     231 for convolution in self.convolutions:
#
# File d:\SLP VC Disentanglement Final\.venv\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File d:\SLP VC Disentanglement Final\.venv\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File d:\SLP VC Disentanglement Final\.venv\Lib\site-packages\torch\nn\modules\rnn.py:1164, in LSTM.forward(self, input, hx)
#    1160         hx = self.permute_hidden(hx, sorted_indices)
#    1162 if batch_sizes is None:
#    1163     # pyrefly: ignore [no-matching-overload]
# -> 1164     result = _VF.lstm(
#    1165         input,
#    1166         hx,
#    1167         self._flat_weights,  # type: ignore[arg-type]
#    1168         self.bias,
#    1169         self.num_layers,
#    1170         self.dropout,
#    1171         self.training,
#    1172         self.bidirectional,
#    1173         self.batch_first,
#    1174     )
#    1175 else:
#    1176     # pyrefly: ignore [no-matching-overload]
#    1177     result = _VF.lstm(
#    1178         input,
#    1179         batch_sizes,
#    (...)   1186         self.bidirectional,
#    1187     )
#
# KeyboardInterrupt:
